# %%
import numpy as np

from my_models import Linear_Regression

x = np.array([
    [4,5],
    [7,9],
    [8,2]
])

y = np.array([37,62,37])

test = np.array([[11,3]])

m1 = Linear_Regression(epochs=1001,alpha = 0.05)
m1.fit(x,y)
# Out:
# Epoch 0: cost = 2194.0000
# Epoch 100: cost = 0.8448
# Epoch 200: cost = 0.7693
# Epoch 300: cost = 0.7006
# Epoch 400: cost = 0.6381
# Epoch 500: cost = 0.5811
# Epoch 600: cost = 0.5292
# Epoch 700: cost = 0.4819
# Epoch 800: cost = 0.4389
# Epoch 900: cost = 0.3997
# Epoch 1000: cost = 0.3640

# %%
m1.plot_cost()

# %%
m1.coefficients
m1.bias
m1.predict(test)
m1.plot_cost_log()
